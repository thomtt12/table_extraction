# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pdf2image

# %%
# !pip install pdf2jpg
# Out:
# ...
#      |████████████████████████████████| 4.3MB 15.8MB/s
# ...
#      |████████████████████████████████| 112kB 58.6MB/s
# ...
#      |████████████████████████████████| 2.0MB 47.7MB/s
# ...
#   Created wheel for pdf2jpg: filename=pdf2jpg-1.0-cp36-none-any.whl size=4287418 sha256=cb44620813606d1ab8d6ea5f2fd0e167a4d46ed2ede1ff11c7dd782a2fc02489
#   Stored in directory: /root/.cache/pip/wheels/bd/dc/72/17e98df36aef90f761a81a74f84414ef16db83fdaa69739909
# ...
#   Created wheel for img2pdf: filename=img2pdf-0.4.0-cp36-none-any.whl size=40503 sha256=138ab57b94eb2f2381626be6a398f429a8a1b1bc17bf6eef7da1afbd5edc2639
#   Stored in directory: /root/.cache/pip/wheels/90/f5/7f/b88a76bac33669118e7549f4856bbe975a3ad2e59280c59196
# Successfully built pdf2jpg img2pdf
# ...

# %%
import os
from pdf2image import convert_from_path

# %%
# from pdf2jpg import pdf2jpg
# inputpath = r"/content/drive/MyDrive/CV-VBD/data-BCTC/BCTC+HN+Q3+2020.pdf"
# outputpath = r"/content/drive/MyDrive/CV-VBD/data-BCTC-image"
# # # To convert single page
# # result = pdf2jpg.convert_pdf2jpg(inputpath, outputpath, pages="1")
# # print(result)

# # # To convert multiple pages
# # result = pdf2jpg.convert_pdf2jpg(inputpath, outputpath, pages="1,0,3")
# # print(result)

# # # to convert all pages
# result = pdf2jpg.convert_pdf2jpg(inputpath, outputpath, pages="ALL")
# print(result)

# %%
# glob.('/content/drive/MyDrive/CV-VBD/data-BCTC')
# Out:
# ['/content/drive/MyDrive/CV-VBD/data-BCTC']

# %%
from pdf2image import convert_from_path
import glob
from pdf2jpg import pdf2jpg

pdf_dir = glob.glob(r"/content/drive/MyDrive/CV-VBD/data_KTTV2/*.pdf")  #your pdf folder path
img_dir = r"/content/drive/MyDrive/CV-VBD/data_KTTV2/img"          #your dest img path

for pdf_ in pdf_dir:
    # pages = convert_from_path(pdf_, 500)
    result = pdf2jpg.convert_pdf2jpg(pdf_, img_dir, pages="ALL")
    # for page in pages:
    #     page.save(img_dir+pdf_.split("/")[-1][:-3]+"jpg", 'JPEG')

# %%
# pdf_dir
# Out:
# []
